# %% [markdown]
# # Ex - GroupBy

# %% [markdown]
# ### Introduction:
#
# GroupBy can be summarized as Split-Apply-Combine.
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# Check out this [Diagram](http://i.imgur.com/yjNkiwL.png)
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks=pd.read_csv(r'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv',sep=',')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
dg=drinks.groupby('continent')
group=dg.mean()
group
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
group[group['beer_servings']==group['beer_servings'].max()].index
# Out:
# Index(['EU'], dtype='object', name='continent')

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
print("AFRICA statistics")
dg.get_group('AF')[['wine_servings']].describe()
# Out:
# AFRICA statistics
#        wine_servings
# count      53.000000
# mean       16.264151
# std        38.846419
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%        13.000000
# max       233.000000

# %%
print("ASIA statistics")
dg.get_group('AS')[['wine_servings']].describe()
# Out:
# ASIA statistics
#        wine_servings
# count      44.000000
# mean        9.068182
# std        21.667034
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         8.000000
# max       123.000000

# %%
print("EUROPE statistics")
dg.get_group('EU')[['wine_servings']].describe()
# Out:
# EUROPE statistics
#        wine_servings
# count      45.000000
# mean      142.222222
# std        97.421738
# min         0.000000
# 25%        59.000000
# 50%       128.000000
# 75%       195.000000
# max       370.000000

# %%
print("OCEANIA statistics")
dg.get_group('OC')[['wine_servings']].describe()
# Out:
# OCEANIA statistics
#        wine_servings
# count       16.00000
# mean        35.62500
# std         64.55579
# min          0.00000
# 25%          1.00000
# 50%          8.50000
# 75%         23.25000
# max        212.00000

# %%
print("SOUTH AMERICA statistics")
dg.get_group('SA')[['wine_servings']].describe()
# Out:
# SOUTH AMERICA statistics
#        wine_servings
# count      12.000000
# mean       62.416667
# std        88.620189
# min         1.000000
# 25%         3.000000
# 50%        12.000000
# 75%        98.500000
# max       221.000000

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
dg.mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
dg.median()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
print('minumum spirit servings')
drinks_min=dg[['spirit_servings']].min()
drinks_min
# Out:
# minumum spirit servings
#            spirit_servings
# continent
# AF                       0
# AS                       0
# EU                       0
# OC                       0
# SA                      25

# %%
print('maxumum spirit servings')
drinks_max=dg[['spirit_servings']].max()
drinks_max
# Out:
# maxumum spirit servings
#            spirit_servings
# continent
# AF                     152
# AS                     326
# EU                     373
# OC                     254
# SA                     302

# %%
print('mean spirit servings')
drinks_mean=dg[['spirit_servings']].mean()
drinks_mean
# Out:
# mean spirit servings
#            spirit_servings
# continent
# AF               16.339623
# AS               60.840909
# EU              132.555556
# OC               58.437500
# SA              114.750000

# %% [markdown]
# # US - Baby Names

# %% [markdown]
# ### Introduction:
#
# We are going to use a subset of [US Baby Names](https://www.kaggle.com/kaggle/us-baby-names) from Kaggle.
# In the file it will be names from 2004 until 2014
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called baby_names.

# %%
baby_names=pd.read_csv(r'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv',sep=',')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %% [markdown]
# ### Step 5. Delete the column 'Unnamed: 0' and 'Id'

# %%
baby_names.drop('Unnamed: 0',inplace=True,axis=1)
baby_names.drop('Id',inplace=True,axis=1)
baby_names.head(10)
# Out:
#        Name  Year Gender State  Count
# 0      Emma  2004      F    AK     62
# 1   Madison  2004      F    AK     48
# 2    Hannah  2004      F    AK     46
# 3     Grace  2004      F    AK     44
# 4     Emily  2004      F    AK     41
# 5   Abigail  2004      F    AK     37
# 6    Olivia  2004      F    AK     33
# 7  Isabella  2004      F    AK     30
# 8    Alyssa  2004      F    AK     29
# 9    Sophia  2004      F    AK     28

# %% [markdown]
# ### Step 6. Is there more male or female names in the dataset?

# %%
if baby_names.Gender.value_counts().index[0]=='F':
    print("Female")
else:
    print("Male")
# Out:
# Female

# %% [markdown]
# ### Step 7. Group the dataset by name and assign to names

# %%
names=baby_names.groupby('Name')
names.first()
# Out:
#          Year Gender State  Count
# Name
# Aaban    2013      M    NY      6
# Aadan    2008      M    CA      7
# Aadarsh  2009      M    IL      5
# Aaden    2007      M    AL      5
# Aadhav   2014      M    CA      6
# ...       ...    ...   ...    ...
# Zyra     2012      F    CA      6
# Zyrah    2011      F    CA      5
# Zyren    2013      M    TX      6
# Zyria    2007      F    GA      6
# Zyriah   2007      F    GA      5
#
# [17632 rows x 4 columns]

# %% [markdown]
# ### Step 8. How many different names exist in the dataset?

# %%
len(names)
# Out:
# 17632

# %% [markdown]
# ### Step 9. What is the name with most occurrences?

# %%
size=baby_names.groupby(['Name']).size()
(size.idxmax(),size.max())
# Out:
# ('Riley', 1112)

# %% [markdown]
# ### Step 10. How many different names have the least occurrences?

# %%
least=0
for i in range(0,len(size)):
    if(size[i]==size.min()):
        print(size.index[i],size[i])
        least=least+1
# Out:
# Aadarsh 1
# Aadhav 1
# Aadin 1
# Aahna 1
# Aaima 1
# Aalaya 1
# Aaminah 1
# Aaniya 1
# Aaria 1
# Aariana 1
# Aarika 1
# Aarini 1
# Aariv 1
# Aarron 1
# Aarvi 1
# Aaryav 1
# Aasha 1
# Aashritha 1
# Aasia 1
# Aayansh 1
# Aayat 1
# Abanoub 1
# Abbiegail 1
# Abdalla 1
# Abdifatah 1
# Abdihafid 1
# Abdikadir 1
# Abdiqani 1
# Abdirahim 1
# Abdishakur 1
# Abdo 1
# Abdon 1
# Abdurahman 1
# Abeeha 1
# Abeer 1
# Abelino 1
# Abenezer 1
# Abhijot 1
# Abhimanyu 1
# Abigaile 1
# Abiha 1
# Aboubakar 1
# Abri 1
# Absidy 1
# Abygale 1
# Access 1
# Acelin 1
# Aceyn 1
# Ackley 1
# Adalae 1
# Adalay 1
# Adaleen 1
# Adalin 1
# Adams 1
# Adanelly 1
# Adanely 1
# Adarian 1
# Adayah 1
# Addalie 1
# Addeline 1
# Addis 1
# Addisson 1
# Adeeb 1
# Adeena 1
# Adelai 1
# Adelayda 1
# Adena 1
# Aderinsola 1
# Adessa 1
# Adhara 1
# Adiana 1
# Adianna 1
# Admir 1
# Adonnis 1
# Adore 1
# Adriane 1
# Adrick 1
# Adrion 1
# Advith 1
# Adyline 1
# Aerianna 1
# Aerilyn 1
# Afnan 1
# Afra 1
# Afsheen 1
# Ahlana 1
# ...

# %%
least
# Out:
# 3682

# %% [markdown]
# ### Step 11. What is the median name occurrence?

# %%
for i in range(0,len(size)):
    if(size[i]==size.median()):
        print(size.index[i],size[i])
# Out:
# Abubakar 8
# Adelie 8
# Adira 8
# Adylene 8
# Aerial 8
# Aidric 8
# Akari 8
# Alaiya 8
# Alara 8
# Alazay 8
# Alder 8
# Aleana 8
# Aleksey 8
# Alin 8
# Alliana 8
# Alon 8
# Alyn 8
# Alysse 8
# Amaryllis 8
# Ambree 8
# Ameir 8
# Amer 8
# Amyri 8
# Andrae 8
# Andriana 8
# Anely 8
# Annahi 8
# Annel 8
# Anshul 8
# Anthoni 8
# Anyiah 8
# Aran 8
# Aristeo 8
# Armonie 8
# Arsema 8
# Artur 8
# Arwa 8
# Athalia 8
# Atley 8
# Audrinna 8
# Audryna 8
# Augusto 8
# Auriana 8
# Avree 8
# Ayannah 8
# Ayumi 8
# Azaleah 8
# Azan 8
# Aziah 8
# Azlyn 8
# Azure 8
# Baily 8
# Baleria 8
# Bea 8
# Bellah 8
# Bentleigh 8
# Berlynn 8
# Blakelyn 8
# Braidyn 8
# Brevin 8
# Breydon 8
# Briyana 8
# Camiya 8
# Candelario 8
# Caydon 8
# Cecile 8
# Cezar 8
# Chani 8
# Chastelyn 8
# Chazz 8
# Che 8
# Chrissy 8
# Clarity 8
# Codey 8
# Cordero 8
# Crista 8
# Curran 8
# Cylas 8
# Cypress 8
# Dagan 8
# Daleysa 8
# Dalyn 8
# Daphnie 8
# Darling 8
# Darvin 8
# Dashel 8
# Dayonna 8
# Denisha 8
# Deseray 8
# Dillinger 8
# ...

# %% [markdown]
# ### Step 12. What is the standard deviation of names?

# %%
np.std(size)
# Out:
# 122.02650299050877

# %% [markdown]
# ### Step 13. Get a summary with the mean, min, max, std and quartiles.

# %%
size.describe()
# Out:
# count    17632.000000
# mean        57.644907
# std        122.029964
# min          1.000000
# 25%          2.000000
# 50%          8.000000
# 75%         39.000000
# max       1112.000000
# dtype: float64
